# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ### **Objectives:**
#
# - List popular languages for Data Science
# - Explore Packages, APIs, Data Sets, and Models
# - Create Jupyter Notebooks and explore JupyterLab
# - Learn about the different R visualization packages and how to create visual charts using the plot function
# - Create a GitHub account and a project repository

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Scikit-learn
# 4. TensorFlow
# 5. PyTorch

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebooks  |
# | RStudio            |
# | VS Code            |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
#
# #### Addition
# print(5 + 3)
#
# #### Subtraction
# print(10 - 4)
#
# #### Multiplication
# print(2 * 6)
#
# #### Division
# print(15 / 3)

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours

# %% [markdown]
# ## Author
# Chase Sinsuan
